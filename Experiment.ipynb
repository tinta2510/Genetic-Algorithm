# %% [markdown]
# # Kết quả thử nghiệm Fine - tuning Parameter GAs cho RTF

# %% [markdown]
# ## Kết quả thử nghiệm cho Round 5:

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
initial_population = [[[290, 90], 3.33], [[140, 30], 3.67], [[60, 10], 6.0], [[90, 40], 6.67], [[40, 10], 8.0], [[130, 90], 9.33], [[90, 60], 10.0],[[90, 60], 10.67], [[100, 70], 11.33], [[180, 140], 14.0]]
population1 = [[[70, 10], 3.67], [[290, 90], 3.67], [[110, 10], 4.0], [[110, 30], 4.67], [[130, 30], 5.0], [[90, 20], 5.33], [[110, 20], 6.67], [[120, 80], 7.0],[[110, 60], 9.67], [[100, 60], 12.0]]
population2 = [[[160, 20], 2.67], [[130, 30], 3.0], [[90, 20], 3.67], [[90, 20], 3.67], [[130, 30], 4.0], [[90, 20], 4.0], [[90, 20], 4.67], [[110, 20], 5.33], [[100,20], 6.0], [[130, 20], 9.0]]
population3 = [[[150, 20], 3.67], [[100, 20], 4.33], [[90, 20], 5.0], [[100, 20], 5.33], [[90, 20], 6.67], [[70, 40], 11.33], [[90, 60], 12.0], [[90, 70], 12.33],[[120, 10], 21.67], [[70, 60], 37.33]]
population4 = [[[90, 10], 2.0], [[160, 10], 2.0], [[130, 10], 3.67], [[120, 10], 4.0], [[150, 20], 4.0], [[130, 10], 4.67], [[90, 10], 5.0], [[180, 60], 5.33], [[90,20], 6.0], [[120, 10], 7.67]]
population5 = [[[90, 10], 2.0], [[170, 50], 2.67], [[100, 10], 3.0], [[110, 20], 3.67], [[220, 40], 3.67], [[120, 10], 4.0], [[170, 30], 4.67], [[180, 60], 5.33],[[80, 10], 5.67], [[130, 10], 20.53]]
population6 = [[[120, 10], 2.0], [[210, 40], 3.33], [[170, 30], 3.33], [[210, 40], 3.67], [[170, 30], 3.67], [[150, 10], 3.67], [[190, 20], 4.67], [[210, 10], 5.33],[[90, 10], 8.0], [[130, 70], 8.33]]
population7 = [[[180, 10], 2.33], [[220, 20], 3.0], [[200, 30], 3.33], [[160, 20], 3.33], [[190, 20], 3.67], [[140, 10], 3.67], [[110, 40], 4.30],[[190, 60], 4.33], [[170, 40], 5.0], [[120, 10], 60.53]]
population8 = [[[220, 20], 2.67], [[200, 20], 2.67], [[120, 10], 3.67], [[220, 70], 4.0], [[140, 10], 4.33], [[160, 10], 5.33], [[120, 10], 7.67],[[230, 10], 2.67], [[180, 10], 3.0], [[190, 20], 3.33], [[140, 10], 9.0], [[150, 10], 10.33]]
population9 = [[[150, 10], 2.0], [[220, 20], 2.33], [[170, 20], 2.67], [[230, 10], 2.67], [[180, 10], 3.0], [[190, 20], 3.33], [[210, 20], 3.33], [[150, 10], 3.33], [[210, 40], 4.33], [[220, 20], 19.67]]
population10 = [[[260, 10], 2.0], [[250, 20], 2.0], [[200, 10], 2.67], [[200, 20], 3.0], [[180, 10], 3.33], [[130, 40], 3.67], [[200, 20], 4.0], [[180, 10], 4.0],[[250, 10], 5.33], [[190, 50], 6.33]]

plt.scatter([i[0][0] for i in initial_population], [i[0][1] for i in initial_population],s = [200 - i[1] for i in initial_population],c = [i[1] for i in initial_population],  cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population1],[i[0][1] for i in population1],s = [200 - i[1] for i in population1],c = [i[1] for i in population1], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population2],[i[0][1] for i in population2],s = [200 - i[1] for i in population2],c = [i[1] for i in population2], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population3],[i[0][1] for i in population3],s = [200 - i[1] for i in population3],c = [i[1] for i in population3], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population4],[i[0][1] for i in population4],s = [200 - i[1] for i in population4],c = [i[1] for i in population4], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population5],[i[0][1] for i in population5],s = [200 - i[1] for i in population5],c = [i[1] for i in population5], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population6],[i[0][1] for i in population6],s = [200 - i[1] for i in population6],c = [i[1] for i in population6], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population7],[i[0][1] for i in population7],s = [200 - i[1] for i in population7],c = [i[1] for i in population7], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population8],[i[0][1] for i in population8],s = [200 - i[1] for i in population8],c = [i[1] for i in population8], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population9],[i[0][1] for i in population9],s = [200 - i[1] for i in population9],c = [i[1] for i in population9], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population10],[i[0][1] for i in population10],s = [200 - i[1] for i in population10],c = [i[1] for i in population10], cmap='nipy_spectral',alpha = 0.5)

plt.xlabel("Population size")
plt.ylabel("Parents number")
plt.title("Round 5")

cbar = plt.colorbar()
cbar.set_label('Generations')
plt.show()

# %% [markdown]
# ### Phân tích kết quả:
# - Từ thanh màu, ta có thể thấy những điểm có màu nằm trong vùng đen - tím là những điểm tốn ít ***generation*** nhất để tìm được kết quả (từ 2-3 generations). Và tương tự, những điểm có màu nằm trong vùng đỏ - trắng sẽ mất nhiều ***generation*** nhất để tìm kết quả (lớn hơn 5.5 generations).
# - Nhìn vào biểu đồ, ta thấy những điểm có màu đen chủ yếu phân bố ở vùng có

# %% [markdown]
# ## Kết quả thử nghiệm cho Round 6:

# %%
# Round 6:
# Chú thích: [population_size,parents_number],generation_to_run
initial_population = [[[250, 60], 7], [[210, 40], 10], [[200, 50], 10], [[70, 30], 19], [[210, 170], 23], [[280, 10], 24], [[90, 60], 30], [[120, 110], 48], [[60, 50], 105], [[240, 200], 132]]
population1 = [[[260, 40], 6], [[160, 30], 7], [[140, 30], 8], [[200, 40], 9], [[90, 30], 15], [[140, 20], 16], [[80, 40], 24], [[230, 20], 36], [[130, 10], 94], [[270, 60], 144]]
population2 = [[[130, 10], 5], [[230, 20], 6], [[290, 50], 6], [[340, 20], 8], [[230, 10], 9], [[250, 30], 11], [[180, 20], 12], [[270, 60], 14], [[210, 20], 15], [[190, 10], 19]]
population3 = [[[290, 10], 3], [[290, 10], 4], [[270, 60], 7], [[190, 10], 8], [[310, 10], 15], [[230, 10], 17], [[200, 10], 28], [[200, 10], 40], [[110, 90], 83], [[130, 20], 87]]
population4 = [[[200, 10], 4], [[320, 30], 5], [[200, 50], 6], [[180, 40], 6], [[270, 60], 6], [[290, 50], 7], [[270, 80], 8], [[130, 10], 24], [[270, 10], 71], [[330, 10], 20160]]
population5 = [[[310, 40], 4], [[320, 50], 5], [[220, 20], 5], [[390, 40], 5], [[300, 40], 7], [[380, 80], 8], [[280, 50], 8], [[130, 30], 9], [[270, 80],12], [[170, 70], 15]]
population6 = [[[430, 50], 3], [[260, 20], 5], [[480, 80], 5], [[350, 60], 6], [[330, 40], 7], [[260, 40], 7], [[300, 50], 7], [[340, 40], 8], [[190, 50],8], [[150, 10], 41]]
population7 = [[[200, 30], 3], [[410, 40], 3], [[460, 50], 4], [[590, 50], 4], [[250, 40], 4], [[390, 60], 6], [[420, 60], 7], [[350, 60], 10], [[230, 10], 11], [[310, 50], 20004]]
population8 = [[[510, 40], 4], [[260, 20], 4], [[200, 40], 4], [[580, 50], 4], [[410, 20], 5], [[510, 50], 5], [[200, 20], 6], [[390, 60], 7], [[380, 10],12], [[430, 20], 66]]
population9 = [[[410, 10], 2], [[690, 40], 3], [[620, 20], 4], [[380, 20], 4], [[510, 40], 5], [[420, 40], 5], [[580, 20], 9], [[120, 30], 10], [[400, 30], 100], [[400, 10], 1661]]
population10 = [[[470, 20], 3], [[420, 20], 4], [[190, 30], 7], [[510, 10], 9], [[420, 40], 13], [[620, 20], 15], [[590, 10], 15], [[670, 10], 16], [[310, 10], 25], [[270, 10], 220]]

plt.scatter([i[0][0] for i in initial_population], [i[0][1] for i in initial_population],s = [200 - i[1] for i in initial_population],c = [i[1] for i in initial_population],  cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population1],[i[0][1] for i in population1],s = [200 - i[1] for i in population1],c = [i[1] for i in population1], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population2],[i[0][1] for i in population2],s = [200 - i[1] for i in population2],c = [i[1] for i in population2], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population3],[i[0][1] for i in population3],s = [200 - i[1] for i in population3],c = [i[1] for i in population3], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population4],[i[0][1] for i in population4],s = [200 - i[1] for i in population4],c = [i[1] for i in population4], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population5],[i[0][1] for i in population5],s = [200 - i[1] for i in population5],c = [i[1] for i in population5], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population6],[i[0][1] for i in population6],s = [200 - i[1] for i in population6],c = [i[1] for i in population6], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population7],[i[0][1] for i in population7],s = [200 - i[1] for i in population7],c = [i[1] for i in population7], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population8],[i[0][1] for i in population8],s = [200 - i[1] for i in population8],c = [i[1] for i in population8], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population9],[i[0][1] for i in population9],s = [200 - i[1] for i in population9],c = [i[1] for i in population9], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population10],[i[0][1] for i in population10],s = [200 - i[1] for i in population10],c = [i[1] for i in population10], cmap='nipy_spectral',alpha = 0.5)

plt.xlabel("Population size")
plt.ylabel("Parents number")
plt.title("Round 6")

cbar = plt.colorbar()
cbar.set_label('Generations')
plt.show()
# Out:
# C:\Users\tatru\AppData\Roaming\Python\Python310\site-packages\matplotlib\collections.py:967: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ## Kết quả thí nghiệm cho Round 7:

# %%
initial_population = [[[160, 50], 46.67], [[250, 100], 74.33], [[290, 30], 506.67], [[290, 120], 725.0], [[180, 130], 806.33], [[20, 10], 1241.33], [[200, 160], 1923.0], [[40, 10], 10332.0], [[270, 130], 10642.33], [[60, 20], 11413.33]] 
population1 = [[[270, 130], 32.33], [[310, 130], 190.0], [[240, 150], 839.67], [[130, 90], 2041.33], [[280, 120], 10031.33], [[270, 130], 10048.0], [[260, 90], 10056.33], [[220, 130], 10069.67], [[300, 140], 10183.33], [[230, 110], 10248.33]]
population2 = [[[260, 80], 32.33], [[310, 130], 42.67], [[250, 60], 84.67], [[270, 130], 96.33], [[270, 130], 474.0], [[280, 110], 4893.33], [[310, 130], 10055.0], [[310, 130], 10170.0], [[230, 140], 20049.0], [[310, 160], 30000.0]]
population3 = [[[280, 90], 42.0], [[260, 80], 431.67], [[260, 10], 516.0], [[280, 110], 1430.33], [[250, 60], 10022.0], [[280, 110], 10067.0], [[290, 110], 10096.67], [[340, 140], 20014.33], [[250, 140], 20226.33], [[270, 60], 30000.0]]
population4 = [[[320, 50], 12.33], [[300, 100], 82.67], [[230, 130], 246.0], [[280, 120], 326.0], [[310, 140], 852.67], [[280, 110], 2094.67], [[270, 90], 10014.0], [[320, 140], 10021.33], [[250, 100], 10114.33], [[290, 110], 10231.33]]

plt.scatter([i[0][0] for i in initial_population], [i[0][1] for i in initial_population],s = 200,c = [i[1] for i in initial_population],  cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population1],[i[0][1] for i in population1],s = 200,c = [i[1] for i in population1], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population2],[i[0][1] for i in population2],s = 200,c = [i[1] for i in population2], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population3],[i[0][1] for i in population3],s = 200,c = [i[1] for i in population3], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population4],[i[0][1] for i in population4],s = 200,c = [i[1] for i in population4], cmap='nipy_spectral',alpha = 0.5)

plt.xlabel("Population size")
plt.ylabel("Parents number")
plt.title("Round 7")

cbar = plt.colorbar()
cbar.set_label('Generations')
plt.show()

# %% [markdown]
# ## Kết quả thí nghiệm Round 12:

# %%
initial_population = [[[70, 30], 3717], [[50, 30], 5796], [[90, 60], 6021], [[20, 10], 8948], [[40, 30], 20000]] 
population1 = [[[50, 30], 3436], [[60, 30], 3618], [[90, 20], 9874], [[90, 60], 14479], [[90, 60], 15216]]
population2 = [[[50, 30], 3436], [[60, 30], 3618], [[90, 20], 9874], [[90, 60], 14479], [[90, 60], 15216]]
population3 = [[[70, 30], 659], [[70, 20], 3619], [[60, 20], 6948], [[80, 20], 7162], [[70, 30], 7717]]
population4 = [[[90, 40], 1005], [[80, 20], 7064], [[70, 30], 10064], [[40, 10], 13488], [[70, 10], 13752]]
population5 = [[[30, 10], 2614], [[80, 20], 2728], [[70, 10], 8529], [[70, 20], 13658], [[20, 20], 20000]]


plt.scatter([i[0][0] for i in initial_population], [i[0][1] for i in initial_population],s = [(30000 - i[1])/50 for i in initial_population],c = [i[1] for i in initial_population],  cmap='nipy_spectral',alpha = 0.5)

plt.scatter([i[0][0] for i in population1],[i[0][1] for i in population1],s = [(30000 - i[1])/50 for i in population1],c = [i[1] for i in population1], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population2],[i[0][1] for i in population2],s = [(30000 - i[1])/50 for i in population2],c = [i[1] for i in population2], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population3],[i[0][1] for i in population3],s = [(30000 - i[1])/50 for i in population3],c = [i[1] for i in population3], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population4],[i[0][1] for i in population4],s = [(30000 - i[1])/50 for i in population4],c = [i[1] for i in population4], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population5],[i[0][1] for i in population5],s = [(30000 - i[1])/50 for i in population5],c = [i[1] for i in population5], cmap='nipy_spectral',alpha = 0.5)


plt.xlabel("Population size")
plt.ylabel("Parents number")
plt.title("Round 12")

cbar = plt.colorbar()
cbar.set_label('Generations')
plt.show()

# %%
population6 = [[[60, 10], 1204], [[60, 20], 1342], [[90, 10], 2951], [[80, 20], 7719], [[40, 10], 8420]]
population7 = [[[70, 10], 3097], [[70, 20], 3819], [[150, 10], 13399], [[60, 20], 13834], [[60, 20], 20000]]
population8 = [[[130, 10], 964], [[150, 20], 2021], [[110, 10], 2515], [[70, 20], 8144], [[50, 10], 11126]]
population9 = [[[130, 10], 840], [[140, 10], 7223], [[130, 10], 8558], [[40, 10], 9964], [[80, 10], 20000]]
population10 = [[[110, 10], 789], [[110, 10], 2384], [[70, 10], 3585], [[170, 10], 7045], [[110, 10], 13428]]

plt.scatter([i[0][0] for i in population6],[i[0][1] for i in population6],s = [(30000 - i[1])/50 for i in population6],c = [i[1] for i in population6], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population7],[i[0][1] for i in population7],s = [(30000 - i[1])/50 for i in population7],c = [i[1] for i in population7], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population8],[i[0][1] for i in population8],s = [(30000 - i[1])/50 for i in population8],c = [i[1] for i in population8], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population9],[i[0][1] for i in population9],s = [(30000 - i[1])/50 for i in population9],c = [i[1] for i in population9], cmap='nipy_spectral',alpha = 0.5)
plt.scatter([i[0][0] for i in population10],[i[0][1] for i in population10],s = [(30000 - i[1])/50 for i in population10],c = [i[1] for i in population10], cmap='nipy_spectral',alpha = 0.5)

plt.xlabel("Population size")
plt.ylabel("Parents number")
plt.title("Round 12")

cbar = plt.colorbar()
cbar.set_label('Generations')
plt.show()
