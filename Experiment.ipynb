# %% [markdown]
# # Kết quả thử nghiệm Fine - tuning Parameter GAs cho RTF

# %%
import matplotlib.pyplot as plt 
import numpy as np 

initial_population = [[[250, 60], 7], [[210, 40], 10], [[200, 50], 10], [[70, 30], 19], [[210, 170], 23], [[280, 10], 24], [[90, 60], 30], [[120, 110], 48], [[60, 50], 105], [[240, 200], 132]]
population1 = [[[260, 40], 6], [[160, 30], 7], [[140, 30], 8], [[200, 40], 9], [[90, 30], 15], [[140, 20], 16], [[80, 40], 24], [[230, 20], 36], [[130, 10], 94], [[270, 60], 144]]

fig, ax = plt.subplots(2)
ax[0].scatter([i[0][0] for i in initial_population], [i[0][1] for i in initial_population],s = 100,c = [i[1] for i in initial_population], cmap = "Greens",alpha = 0.75)
ax[1].scatter([i[0][0] for i in population1],[i[0][1] for i in population1],s = 100,c = [i[1] for i in population1], cmap="Greens",alpha = 0.75)
#cbar = plt.colorbar()
#cbar.set_label('generation')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 10
#       8 ax[0].scatter([i[0][0] for i in initial_population], [i[0][1] for i in initial_population],s = 100,c = [i[1] for i in initial_population], cmap = "Greens",alpha = 0.75)
#       9 ax[1].scatter([i[0][0] for i in population1],[i[0][1] for i in population1],s = 100,c = [i[1] for i in population1], cmap="Greens",alpha = 0.75)
# ---> 10 cbar = plt.colorbar()
#      11 cbar.set_label('generation')
#      12 plt.show()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\pyplot.py:2061, in colorbar(mappable, cax, ax, **kwargs)
#    2059     mappable = gci()
#    2060     if mappable is None:
# -> 2061         raise RuntimeError('No mappable was found to use for colorbar '
#    2062                            'creation. First define a mappable such as '
#    2063                            'an image (with imshow) or a contour set ('
#    2064                            'with contourf).')
#    2065 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2066 return ret
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).
